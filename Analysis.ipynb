# %%
import pandas as pd
data = pd.read_csv("C:/Users/joses/Downloads/myexcel.csv")
data
# Out:
#               Name            Team  Number Position  Age  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     235
# 2     John Holland  Boston Celtics      30       SG   27     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     231
# ..             ...             ...     ...      ...  ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     203
# 454      Raul Neto       Utah Jazz      25       PG   24     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     256
# 456    Jeff Withey       Utah Jazz      24        C   26     231
# 457       Priyanka       Utah Jazz      34        C   25     231
#
#                College     Salary  Height
# 0                Texas  7730337.0     160
# 1            Marquette  6796117.0     160
# 2    Boston University        NaN     160
# ...

# %%
data.isnull().sum()
# Out:
# Name         0
# Team         0
# Number       0
# Position     0
# Age          0
# Weight       0
# College     84
# Salary      11
# Height       0
# dtype: int64

# %%
data['College'].fillna('new college')
# Out:
# 0                  Texas
# 1              Marquette
# 2      Boston University
# 3          Georgia State
# 4            new college
#              ...
# 453               Butler
# 454          new college
# 455          new college
# 456               Kansas
# 457               Kansas
# Name: College, Length: 458, dtype: object

# %%
data['Salary'].fillna('10000')
# Out:
# 0      7730337.0
# 1      6796117.0
# 2          10000
# 3      1148640.0
# 4      5000000.0
#          ...
# 453    2433333.0
# 454     900000.0
# 455    2900000.0
# 456     947276.0
# 457     947276.0
# Name: Salary, Length: 458, dtype: object

# %%
data.duplicated().sum()
# Out:
# 0

# %%
df = pd.DataFrame(data)

# Task 1: Distribution of employees across each team
team_distribution = df['Team'].value_counts()
total_employees = len(df)
team_percentage = (team_distribution / total_employees) * 100

print("Team Distribution:\n", team_distribution)
print("\nTeam Percentage:\n", team_percentage)
# Out:
# Team Distribution:
#  Team
# New Orleans Pelicans      19
# Memphis Grizzlies         18
# Utah Jazz                 16
# New York Knicks           16
# Milwaukee Bucks           16
# Brooklyn Nets             15
# Portland Trail Blazers    15
# Oklahoma City Thunder     15
# Denver Nuggets            15
# Washington Wizards        15
# Miami Heat                15
# Charlotte Hornets         15
# Atlanta Hawks             15
# San Antonio Spurs         15
# Houston Rockets           15
# Boston Celtics            15
# Indiana Pacers            15
# Detroit Pistons           15
# Cleveland Cavaliers       15
# Chicago Bulls             15
# Sacramento Kings          15
# Phoenix Suns              15
# Los Angeles Lakers        15
# Los Angeles Clippers      15
# Golden State Warriors     15
# Toronto Raptors           15
# Philadelphia 76ers        15
# Dallas Mavericks          15
# Orlando Magic             14
# Minnesota Timberwolves    14
# Name: count, dtype: int64
#
# ...

# %%
# Task 2: Segregate employees based on their positions
position_distribution = df['Position'].value_counts()
print("\nPosition Distribution:\n", position_distribution)
# Out:
# Position Distribution:
#  Position
# SG    102
# PF    100
# PG     92
# SF     85
# C      79
# Name: count, dtype: int64

# %%
# Task 3: Identify the predominant age group among employees
age_groups = pd.cut(df['Age'], bins=[20, 25, 30, 35,40,45], labels=["20-25", "26-30", "31-35","36-40","41-45"])
age_group_distribution = age_groups.value_counts()
print("\nAge Group Distribution:\n", age_group_distribution)
# Out:
# Age Group Distribution:
#  Age
# 20-25    179
# 26-30    167
# 31-35     68
# 36-40     23
# 41-45      0
# Name: count, dtype: int64

# %%
# Task 4: Highest salary expenditure by team and position
df['Salary'] = df['Salary'].fillna(0)
team_salary_expenditure = df.groupby('Team')['Salary'].sum()
position_salary_expenditure = df.groupby('Position')['Salary'].sum()
highest_team_salary = team_salary_expenditure.idxmax()
highest_position_salary = position_salary_expenditure.idxmax()

print("\nTeam with Highest Salary Expenditure:", highest_team_salary)
print("Position with Highest Salary Expenditure:", highest_position_salary)
# Out:
# Team with Highest Salary Expenditure: Cleveland Cavaliers
# Position with Highest Salary Expenditure: C

# %%
# Task 5: Correlation between age and salary
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Age', y='Salary', data=df)
plt.title('Relation between Age and Salary')
plt.xlabel('Age')
plt.ylabel('Salary')
plt.show()

# %%
# Task 1: Team Distribution
plt.figure(figsize=(10, 6))
sns.barplot(x=team_distribution.index, y=team_distribution.values, palette="viridis")
plt.title('Team Distribution')
plt.xlabel('Team')
plt.ylabel('Number of Employees')
plt.xticks(rotation=45)
plt.show()
# Task 1: Team Distribution Percentage
plt.figure(figsize=(10, 6))
sns.barplot(x=team_percentage.index, y=team_percentage.values, palette="magma")
plt.title('Team Distribution Percentage')
plt.xlabel('Team')
plt.ylabel('Percentage (%)')
plt.xticks(rotation=45)
plt.show()

# %%
# Task 2: Segregation of employees based on their positions
plt.figure(figsize=(5, 3))
sns.countplot(x='Position', data=df, palette="Set2")
plt.title('Position Distribution')
plt.xlabel('Position')
plt.ylabel('Number of Employees')
plt.xticks(rotation=45)
plt.show()

# %%
# Task 3: Predominant age group among employees
plt.figure(figsize=(5, 3))
age_group_distribution.plot(kind='bar', color='red')
plt.title('Predominant Age Group Among Employees')
plt.xlabel('Age Group')
plt.ylabel('Number of Employees')
plt.show()

# %%
# Task 4: Highest Salary Expenditure by Team and Position
plt.figure(figsize=(12, 6))
sns.barplot(x=team_salary_expenditure.index, y=team_salary_expenditure.values, palette="coolwarm")
plt.title('Total Salary Expenditure by Team')
plt.xlabel('Team')
plt.ylabel('Total Salary ($)')
plt.xticks(rotation=45)
plt.show()

# %%
# Task 4: Highest salary expenditure by team and position
plt.figure(figsize=(5, 3))
sns.barplot(x=position_salary_expenditure.index, y=position_salary_expenditure.values, palette="coolwarm")
plt.title('Total Salary Expenditure by Position')
plt.xlabel('Position')
plt.ylabel('Total Salary ($)')
plt.xticks(rotation=45)
plt.show()

# %%
# Task 5: Correlation between Age and Salary
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Age', y='Salary', data=df, s=100, alpha=0.7, hue='Team')
plt.title('Relation between Age and Salary')
plt.xlabel('Age')
plt.ylabel('Salary ($)')
plt.legend(loc='best')
plt.show()

# %%
Data Story: Insights from the Analysis
----------------------------------------
1. Team Distribution
The New Orlean Pelicans have the highest number of employees.
Percentage-wise, the New Orlean Pelicans make up approximately 4.2% of the total team.
    
2. Position Distribution
The most common position is SG.
Other prominent positions include PG and PF.

3. Predominant Age Group
The predominant age group is 20-30.

4. Highest Salary Expenditure
Chicago Bulls have the highest total salary expenditure.

5. Correlation between Age and Salary
From this, Age is not a factor of salary

These insights provide a comprehensive understanding of the team's dynamics,
highlighting key trends in team composition, positional roles, age distribution, and salary allocation.
This analysis can aid in strategic planning, resource allocation, and performance evaluation.
# Out:
#   Cell In[17], line 20
#     These insights provide a comprehensive understanding of the team's dynamics,
#                                                                     ^
# SyntaxError: unterminated string literal (detected at line 20)
